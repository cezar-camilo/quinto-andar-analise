# %%
import pandas as pd

# %%
df = pd.read_csv("imoveis_detalhados.csv", sep=',', encoding='utf-8')
df.head()
# Out:
#     aluguel  condominio   iptu seguro_incendio taxa_servico     total  \
# 0  R$ 1.159    Corrimão  R$ 28           R$ 20        R$ 30  R$ 1.734
# 1  R$ 1.374  Playground   R$ 0           R$ 19        R$ 27  R$ 1.722
# 2  R$ 1.657      R$ 580  R$ 66           R$ 24        R$ 42  R$ 2.369
# 3  R$ 1.273  Playground  R$ 55           R$ 21        R$ 32  R$ 1.768
# 4    R$ 903    Elevador  R$ 36           R$ 15        R$ 23  R$ 1.402
#
#                                     bairro metragem    quartos   banheiros  \
# 0    Samambaia Norte (samambaia), Brasília    46 m²  2 quartos  1 banheiro
# 1      Ceilândia Sul (ceilândia), Brasília    55 m²  2 quartos  1 banheiro
# 2           Norte (águas Claras), Brasília    40 m²   1 quarto  1 banheiro
# 3  Taguatinga Norte (taguatinga), Brasília    45 m²  2 quartos  1 banheiro
# 4      Samambaia Sul (samambaia), Brasília    49 m²  2 quartos  1 banheiro
#
#     vagas            andar  aceita_pet  sem_mobilia  latitude  longitude
# ...
